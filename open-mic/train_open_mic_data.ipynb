# %% [markdown]
# <a href="https://colab.research.google.com/github/fireHedgehog/music-intrument-OvA-model/blob/main/open-mic/train_open_mic_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. mount the google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np

# Load the HDF5 file and create X_train
def load_hdf5_file(hdf5_file_path):
    with h5py.File(hdf5_file_path, 'r') as hdf5_file:
        X_train = []
        sample_keys = []
        for sample_key in hdf5_file.keys():
            spectrogram = hdf5_file[sample_key][:]
            X_train.append(spectrogram)
            sample_keys.append(sample_key)
    return X_train, sample_keys

# %%
# Load the metadata file
metadata_file = '/content/drive/My Drive/datasets/openmic-2018/openmic-2018/openmic-2018-aggregated-labels.csv'
metadata = pd.read_csv(metadata_file)

# %%
# Load the training HDF5 file
train_hdf5_file_path = '/content/drive/My Drive/datasets/openmic-2018/train_spectrograms.h5'
X_train, sample_keys = load_hdf5_file(train_hdf5_file_path)

# %%
import numpy as np

# Convert X_train to a numpy array
X_train = np.array(X_train)

# Example usage
print("x_train shape:", X_train.shape)
print("x_train[0]:", X_train[0])
# Out:
# x_train shape: (14915, 218, 800)
# x_train[0]: [[0.10258293 0.14368583 0.21555336 ... 0.60530014 0.62167129 0.63103437]
#  [0.17451057 0.22862051 0.32323059 ... 0.65854224 0.67061877 0.67752564]
#  [0.22467108 0.29214791 0.41012971 ... 0.86246766 0.8555632  0.85161436]
#  ...
#  [0.38949594 0.39086323 0.39325392 ... 0.38257781 0.37605065 0.37231759]
#  [0.38949594 0.39086323 0.39325392 ... 0.38257781 0.37605065 0.37231759]
#  [0.38949594 0.39086323 0.39325392 ... 0.38257781 0.37605065 0.37231759]]

# %%
# Expand dimensions of x_train to add the channel dimension
X_train = np.expand_dims(X_train, axis=-1)

# Example usage
# print("x_train shape:", X_train.shape)
# print("x_train[0]:", X_train[0])

# %%
# Extract and weight y_train
y_train_list = []
weights_list = []
for sample_key in sample_keys:
    sample_metadata = metadata[metadata["sample_key"] == sample_key]
    labels = sample_metadata[sample_metadata["relevance"] > 0.0]["instrument"].tolist()
    relevance_scores = sample_metadata[sample_metadata["relevance"] > 0.0]["relevance"].tolist()
    y_train_list.append(set(labels))
    if relevance_scores:
        weights_list.append(np.mean(relevance_scores))
    else:
        weights_list.append(1.0)  # Default weight if no relevance score

mlb = MultiLabelBinarizer()
y_train = mlb.fit_transform(y_train_list)

# Example usage
print("X_train shape:", X_train.shape)
print("X_train[0] shape:", X_train[0].shape if len(X_train) > 0 else "No data")
print("y_train shape:", y_train.shape)
print("Classes:", mlb.classes_)
# Out:
# X_train shape: (14915, 218, 800, 1)
# X_train[0] shape: (218, 800, 1)
# y_train shape: (14915, 20)
# Classes: ['accordion' 'banjo' 'bass' 'cello' 'clarinet' 'cymbals' 'drums' 'flute'
#  'guitar' 'mallet_percussion' 'mandolin' 'organ' 'piano' 'saxophone'
#  'synthesizer' 'trombone' 'trumpet' 'ukulele' 'violin' 'voice']

# %%
# Load the testing HDF5 file
test_hdf5_file_path = '/content/drive/My Drive/datasets/openmic-2018/test_spectrograms.h5'
X_test, test_sample_keys = load_hdf5_file(test_hdf5_file_path)

# Convert X_test to a numpy array
X_test = np.array(X_test)


print("X_test shape:", X_test.shape)
print("X_test[0] shape:", X_test[0].shape if len(X_test) > 0 else "No data")
# Out:
# X_test shape: (5085, 218, 800)
# X_test[0] shape: (218, 800)

# %%
# Expand dimensions of X_test to add the channel dimension
X_test = np.expand_dims(X_test, axis=-1)

# Example usage
# print("X_test shape:", X_test.shape)
# print("X_test[0]:", X_test[0])

# %%
# Extract and binarize y_test using the fitted mlb
y_test_list = []
for sample_key in test_sample_keys:
    sample_metadata = metadata[metadata["sample_key"] == sample_key]
    labels = sample_metadata[sample_metadata["relevance"] > 0.0]["instrument"].tolist()
    y_test_list.append(set(labels))

# reuse the training one
y_test = mlb.transform(y_test_list)
print("y_test shape:", y_test.shape)
# Out:
# y_test shape: (5085, 20)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Multiply, Add, Activation,Dropout,BatchNormalization
from tensorflow.keras.models import Model
from sklearn.preprocessing import MultiLabelBinarizer
import pandas as pd

# %%
# Modify channel_attention and coordinate_attention to return attention maps
def channel_attention(input_feature, ratio=8):
    channel = input_feature.shape[-1]

    shared_layer_one = Dense(channel // ratio,
                             activation='relu',
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')
    shared_layer_two = Dense(channel,
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')

    avg_pool = GlobalAveragePooling2D()(input_feature)
    avg_pool = Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)

    max_pool = GlobalMaxPooling2D()(input_feature)
    max_pool = Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)

    cbam_feature = Add()([avg_pool, max_pool])
    cbam_feature = Activation('sigmoid')(cbam_feature)

    attention_map = Multiply()([input_feature, cbam_feature])
    return attention_map, cbam_feature

# %%
def coordinate_attention(inputs, reduction_ratio=8):
    def h_swish(x):
        return x * tf.nn.relu6(x + 3) / 6

    _, h, w, c = inputs.shape

    h_avg_pool = tf.reduce_mean(inputs, axis=2, keepdims=True)
    w_avg_pool = tf.reduce_mean(inputs, axis=1, keepdims=True)

    h_avg_pool = tf.transpose(h_avg_pool, [0, 2, 1, 3])
    h_avg_pool = Conv2D(filters=c // reduction_ratio, kernel_size=1, activation=h_swish)(h_avg_pool)
    h_avg_pool = Conv2D(filters=c, kernel_size=1, activation='sigmoid')(h_avg_pool)
    h_avg_pool = tf.transpose(h_avg_pool, [0, 2, 1, 3])

    w_avg_pool = Conv2D(filters=c // reduction_ratio, kernel_size=1, activation=h_swish)(w_avg_pool)
    w_avg_pool = Conv2D(filters=c, kernel_size=1, activation='sigmoid')(w_avg_pool)

    attention_map = inputs * h_avg_pool * w_avg_pool
    return attention_map, h_avg_pool, w_avg_pool

# %%
from re import X

"""
def create_training_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu')(inputs)
    x = MaxPooling2D((2, 2))(x)

    # Apply channel attention
    x, _ = channel_attention(x)

    x = Conv2D(64, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)

    # Apply coordinate attention
    x, _, _ = coordinate_attention(x)

    # Additional pooling layer to reduce dimensionality
    x = MaxPooling2D((2, 2))(x)

    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    outputs = Dense(num_classes, activation='sigmoid')(x)  # Use sigmoid for multi-label classification

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

"""

def create_training_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    x = Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
     # print(f"Shape after Conv2D(32): {x.shape}")
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
     # print(f"Shape after MaxPooling2D: {x.shape}")

    x, _, _ = coordinate_attention(x) # early attention

    x = Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
     # print(f"Shape after Conv2D(64): {x.shape}")
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
     # print(f"Shape after MaxPooling2D: {x.shape}")

    x, _, _ = coordinate_attention(x) # mid attention

    x = Conv2D(128, kernel_size=(3, 3), activation='relu')(x)
     # print(f"Shape after Conv2D(128): {x.shape}")
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
     # print(f"Shape after MaxPooling2D: {x.shape}")

    x = Conv2D(256, kernel_size=(3, 3), activation='relu')(x)
     # print(f"Shape after Conv2D(256): {x.shape}")
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
     # print(f"Shape after MaxPooling2D: {x.shape}")

    x, _ = channel_attention(x)
     # print(f"Shape after channel_attention: {x.shape}")
    x, _, _ = coordinate_attention(x)
     # print(f"Shape after coordinate_attention: {x.shape}")

    x = Flatten()(x)
     # print(f"Shape after Flatten: {x.shape}")
    x = Dense(512, activation='relu')(x)
     # print(f"Shape after Dense(512): {x.shape}")
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='sigmoid')(x)  # Use sigmoid for multi-label classification
     # print(f"Shape after Dense(output): {outputs.shape}")

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'], weighted_metrics=['accuracy'])
    return model

input_shape = (218, 800, 1)
num_classes = y_train.shape[1]

print(f"Input shape: {input_shape}")

print(f"Number of classes: {num_classes}")
training_model = create_training_model(input_shape, num_classes)

training_model.summary()
# Out:
# Input shape: (218, 800, 1)
# Number of classes: 20
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 218, 800, 1)]        0         []
#
#  conv2d_8 (Conv2D)           (None, 216, 798, 32)         320       ['input_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 216, 798, 32)         128       ['conv2d_8[0][0]']
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 108, 399, 32)         0         ['batch_normalization_4[0][0]'
#  g2D)                                                               ]
#
#  tf.math.reduce_mean_2 (TFO  (None, 108, 1, 32)           0         ['max_pooling2d_4[0][0]']
#  pLambda)
#
#  tf.compat.v1.transpose_2 (  (None, 1, 108, 32)           0         ['tf.math.reduce_mean_2[0][0]'
#  TFOpLambda)                                                        ]
#
#  conv2d_9 (Conv2D)           (None, 1, 108, 4)            132       ['tf.compat.v1.transpose_2[0][
#                                                                     0]']
#
#  conv2d_10 (Conv2D)          (None, 1, 108, 32)           160       ['conv2d_9[0][0]']
#
#  tf.math.reduce_mean_3 (TFO  (None, 1, 399, 32)           0         ['max_pooling2d_4[0][0]']
#  pLambda)
#
#  tf.compat.v1.transpose_3 (  (None, 108, 1, 32)           0         ['conv2d_10[0][0]']
#  TFOpLambda)
#
#  conv2d_11 (Conv2D)          (None, 1, 399, 4)            132       ['tf.math.reduce_mean_3[0][0]'
#                                                                     ]
#
#  tf.math.multiply_2 (TFOpLa  (None, 108, 399, 32)         0         ['max_pooling2d_4[0][0]',
#  mbda)                                                               'tf.compat.v1.transpose_3[0][
#                                                                     0]']
#
#  conv2d_12 (Conv2D)          (None, 1, 399, 32)           160       ['conv2d_11[0][0]']
#
#  tf.math.multiply_3 (TFOpLa  (None, 108, 399, 32)         0         ['tf.math.multiply_2[0][0]',
#  mbda)                                                               'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 106, 397, 64)         18496     ['tf.math.multiply_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 106, 397, 64)         256       ['conv2d_13[0][0]']
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 53, 198, 64)          0         ['batch_normalization_5[0][0]'
#  g2D)                                                               ]
#
#  tf.math.reduce_mean_4 (TFO  (None, 53, 1, 64)            0         ['max_pooling2d_5[0][0]']
#  pLambda)
#
#  tf.compat.v1.transpose_4 (  (None, 1, 53, 64)            0         ['tf.math.reduce_mean_4[0][0]'
#  TFOpLambda)                                                        ]
#
#  conv2d_14 (Conv2D)          (None, 1, 53, 8)             520       ['tf.compat.v1.transpose_4[0][
#                                                                     0]']
#
#  conv2d_15 (Conv2D)          (None, 1, 53, 64)            576       ['conv2d_14[0][0]']
#
#  tf.math.reduce_mean_5 (TFO  (None, 1, 198, 64)           0         ['max_pooling2d_5[0][0]']
#  pLambda)
#
#  tf.compat.v1.transpose_5 (  (None, 53, 1, 64)            0         ['conv2d_15[0][0]']
#  TFOpLambda)
#
#  conv2d_16 (Conv2D)          (None, 1, 198, 8)            520       ['tf.math.reduce_mean_5[0][0]'
#                                                                     ]
#
#  tf.math.multiply_4 (TFOpLa  (None, 53, 198, 64)          0         ['max_pooling2d_5[0][0]',
#  mbda)                                                               'tf.compat.v1.transpose_5[0][
#                                                                     0]']
#
#  conv2d_17 (Conv2D)          (None, 1, 198, 64)           576       ['conv2d_16[0][0]']
#
#  tf.math.multiply_5 (TFOpLa  (None, 53, 198, 64)          0         ['tf.math.multiply_4[0][0]',
#  mbda)                                                               'conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 51, 196, 128)         73856     ['tf.math.multiply_5[0][0]']
#
#  batch_normalization_6 (Bat  (None, 51, 196, 128)         512       ['conv2d_18[0][0]']
#  chNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 25, 98, 128)          0         ['batch_normalization_6[0][0]'
#  g2D)                                                               ]
#
#  conv2d_19 (Conv2D)          (None, 23, 96, 256)          295168    ['max_pooling2d_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 23, 96, 256)          1024      ['conv2d_19[0][0]']
#  chNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 11, 48, 256)          0         ['batch_normalization_7[0][0]'
#  g2D)                                                               ]
#
#  global_average_pooling2d_1  (None, 256)                  0         ['max_pooling2d_7[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_1 (Gl  (None, 256)                  0         ['max_pooling2d_7[0][0]']
#  obalMaxPooling2D)
#
#  reshape_2 (Reshape)         (None, 1, 1, 256)            0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  reshape_3 (Reshape)         (None, 1, 1, 256)            0         ['global_max_pooling2d_1[0][0]
#                                                                     ']
#
#  dense_4 (Dense)             (None, 1, 1, 32)             8224      ['reshape_2[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  dense_5 (Dense)             (None, 1, 1, 256)            8448      ['dense_4[0][0]',
#                                                                      'dense_4[1][0]']
#
#  add_1 (Add)                 (None, 1, 1, 256)            0         ['dense_5[0][0]',
#                                                                      'dense_5[1][0]']
#
#  activation_1 (Activation)   (None, 1, 1, 256)            0         ['add_1[0][0]']
#
#  multiply_1 (Multiply)       (None, 11, 48, 256)          0         ['max_pooling2d_7[0][0]',
#                                                                      'activation_1[0][0]']
#
#  tf.math.reduce_mean_6 (TFO  (None, 11, 1, 256)           0         ['multiply_1[0][0]']
#  pLambda)
#
#  tf.compat.v1.transpose_6 (  (None, 1, 11, 256)           0         ['tf.math.reduce_mean_6[0][0]'
#  TFOpLambda)                                                        ]
#
#  conv2d_20 (Conv2D)          (None, 1, 11, 32)            8224      ['tf.compat.v1.transpose_6[0][
#                                                                     0]']
#
#  conv2d_21 (Conv2D)          (None, 1, 11, 256)           8448      ['conv2d_20[0][0]']
#
#  tf.math.reduce_mean_7 (TFO  (None, 1, 48, 256)           0         ['multiply_1[0][0]']
#  pLambda)
#
#  tf.compat.v1.transpose_7 (  (None, 11, 1, 256)           0         ['conv2d_21[0][0]']
#  TFOpLambda)
#
#  conv2d_22 (Conv2D)          (None, 1, 48, 32)            8224      ['tf.math.reduce_mean_7[0][0]'
#                                                                     ]
#
#  tf.math.multiply_6 (TFOpLa  (None, 11, 48, 256)          0         ['multiply_1[0][0]',
#  mbda)                                                               'tf.compat.v1.transpose_7[0][
#                                                                     0]']
#
#  conv2d_23 (Conv2D)          (None, 1, 48, 256)           8448      ['conv2d_22[0][0]']
#
#  tf.math.multiply_7 (TFOpLa  (None, 11, 48, 256)          0         ['tf.math.multiply_6[0][0]',
#  mbda)                                                               'conv2d_23[0][0]']
#
#  flatten_1 (Flatten)         (None, 135168)               0         ['tf.math.multiply_7[0][0]']
#
#  dense_6 (Dense)             (None, 512)                  6920652   ['flatten_1[0][0]']
#                                                           8
#
#  dropout_1 (Dropout)         (None, 512)                  0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 20)                   10260     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 69659340 (265.73 MB)
# Trainable params: 69658380 (265.73 MB)
# Non-trainable params: 960 (3.75 KB)
# __________________________________________________________________________________________________

# %%
# better to shuffle the data
from sklearn.utils import shuffle
weights_array = np.array(weights_list)

# Ensure weights match the number of samples and one-hot encoding
X_train, y_train, weights_array = shuffle(X_train, y_train, weights_array, random_state=36)

# %%
"""
from tensorflow.keras.utils import Sequence
import numpy as np

class AudioDataGenerator(Sequence):
    def __init__(self, x_set, y_set, batch_size):
        self.x, self.y = x_set, y_set
        self.batch_size = batch_size

    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))

    def __getitem__(self, idx):
        batch_x = self.x[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]

        # Apply augmentations
        augmented_batch_x = np.array([self.augment(spec) for spec in batch_x])

        return augmented_batch_x, batch_y

    def augment(self, spectrogram):
        # Time stretching
        stretch_factor = np.random.uniform(0.8, 1.2)
        time_stretched = np.interp(np.linspace(0, 1, spectrogram.shape[1]),
                                   np.linspace(0, 1, int(spectrogram.shape[1] * stretch_factor)),
                                   spectrogram)

        # Frequency masking
        freq_mask_param = 20
        num_masks = 2
        for _ in range(num_masks):
            f0 = np.random.randint(0, spectrogram.shape[0] - freq_mask_param)
            time_stretched[f0:f0+freq_mask_param, :] = 0

        return time_stretched

# Split the data for validation
val_split = 0.2
split_idx = int(len(X_train) * (1 - val_split))
X_train_split, X_val = X_train[:split_idx], X_train[split_idx:]
y_train_split, y_val = y_train[:split_idx], y_train[split_idx:]

# Create the data generator for training data only
train_generator = AudioDataGenerator(X_train_split, y_train_split, batch_size=32)

steps_per_epoch = len(X_train_split) // 32  # batch size is

history = training_model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=200,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, lr_reducer]
)


"""

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


early_stopping = EarlyStopping(patience=80, restore_best_weights=True)
lr_reducer = ReduceLROnPlateau(factor=0.1, patience=40)

history = training_model.fit(
    X_train,
    y_train,
    epochs=500,
    batch_size=32,
    validation_split=0.2,
    sample_weight=weights_array,
    callbacks=[early_stopping, lr_reducer]
)

# Save the model
model_save_path = '/content/drive/My Drive/datasets/openmic-2018/model_with_attention.tf'
training_model.save(model_save_path)

# Save the training history
history_df = pd.DataFrame(history.history)
history_df.to_csv('/content/drive/My Drive/datasets/openmic-2018/training_history_with_attention.csv', index=False)

print("Model and training history saved successfully.")
# Out:
# Epoch 1/500
# 373/373 [==============================] - 42s 90ms/step - loss: 0.1821 - accuracy: 0.1545 - weighted_accuracy: 0.1669 - val_loss: 0.2284 - val_accuracy: 0.0815 - val_weighted_accuracy: 0.0820 - lr: 0.0010
# Epoch 2/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.1376 - accuracy: 0.2421 - weighted_accuracy: 0.2618 - val_loss: 0.1284 - val_accuracy: 0.2913 - val_weighted_accuracy: 0.3063 - lr: 0.0010
# Epoch 3/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.1223 - accuracy: 0.2968 - weighted_accuracy: 0.3213 - val_loss: 0.1254 - val_accuracy: 0.3215 - val_weighted_accuracy: 0.3273 - lr: 0.0010
# Epoch 4/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.1075 - accuracy: 0.3514 - weighted_accuracy: 0.3791 - val_loss: 0.1224 - val_accuracy: 0.2729 - val_weighted_accuracy: 0.2941 - lr: 0.0010
# Epoch 5/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0949 - accuracy: 0.3988 - weighted_accuracy: 0.4307 - val_loss: 0.1089 - val_accuracy: 0.3631 - val_weighted_accuracy: 0.3829 - lr: 0.0010
# Epoch 6/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0784 - accuracy: 0.4492 - weighted_accuracy: 0.4888 - val_loss: 0.1129 - val_accuracy: 0.3543 - val_weighted_accuracy: 0.3772 - lr: 0.0010
# Epoch 7/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0631 - accuracy: 0.5022 - weighted_accuracy: 0.5438 - val_loss: 0.1257 - val_accuracy: 0.3429 - val_weighted_accuracy: 0.3619 - lr: 0.0010
# Epoch 8/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0485 - accuracy: 0.5437 - weighted_accuracy: 0.5827 - val_loss: 0.1266 - val_accuracy: 0.3453 - val_weighted_accuracy: 0.3715 - lr: 0.0010
# Epoch 9/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0390 - accuracy: 0.5703 - weighted_accuracy: 0.6068 - val_loss: 0.1377 - val_accuracy: 0.3560 - val_weighted_accuracy: 0.3721 - lr: 0.0010
# Epoch 10/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0319 - accuracy: 0.5934 - weighted_accuracy: 0.6219 - val_loss: 0.1492 - val_accuracy: 0.3403 - val_weighted_accuracy: 0.3656 - lr: 0.0010
# Epoch 11/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0270 - accuracy: 0.6081 - weighted_accuracy: 0.6315 - val_loss: 0.1663 - val_accuracy: 0.3312 - val_weighted_accuracy: 0.3591 - lr: 0.0010
# Epoch 12/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0243 - accuracy: 0.6185 - weighted_accuracy: 0.6361 - val_loss: 0.1686 - val_accuracy: 0.3446 - val_weighted_accuracy: 0.3633 - lr: 0.0010
# Epoch 13/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0213 - accuracy: 0.6264 - weighted_accuracy: 0.6399 - val_loss: 0.1755 - val_accuracy: 0.3409 - val_weighted_accuracy: 0.3578 - lr: 0.0010
# Epoch 14/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0193 - accuracy: 0.6369 - weighted_accuracy: 0.6445 - val_loss: 0.1636 - val_accuracy: 0.3004 - val_weighted_accuracy: 0.3213 - lr: 0.0010
# Epoch 15/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0175 - accuracy: 0.6497 - weighted_accuracy: 0.6533 - val_loss: 0.1772 - val_accuracy: 0.3208 - val_weighted_accuracy: 0.3480 - lr: 0.0010
# Epoch 16/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0159 - accuracy: 0.6505 - weighted_accuracy: 0.6511 - val_loss: 0.1750 - val_accuracy: 0.3151 - val_weighted_accuracy: 0.3393 - lr: 0.0010
# Epoch 17/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0155 - accuracy: 0.6530 - weighted_accuracy: 0.6497 - val_loss: 0.1922 - val_accuracy: 0.3326 - val_weighted_accuracy: 0.3536 - lr: 0.0010
# Epoch 18/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0146 - accuracy: 0.6622 - weighted_accuracy: 0.6586 - val_loss: 0.1969 - val_accuracy: 0.3429 - val_weighted_accuracy: 0.3590 - lr: 0.0010
# Epoch 19/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0129 - accuracy: 0.6654 - weighted_accuracy: 0.6573 - val_loss: 0.1879 - val_accuracy: 0.3419 - val_weighted_accuracy: 0.3601 - lr: 0.0010
# Epoch 20/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0129 - accuracy: 0.6633 - weighted_accuracy: 0.6571 - val_loss: 0.2016 - val_accuracy: 0.3275 - val_weighted_accuracy: 0.3491 - lr: 0.0010
# Epoch 21/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0114 - accuracy: 0.6696 - weighted_accuracy: 0.6589 - val_loss: 0.2009 - val_accuracy: 0.3329 - val_weighted_accuracy: 0.3526 - lr: 0.0010
# Epoch 22/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0115 - accuracy: 0.6689 - weighted_accuracy: 0.6586 - val_loss: 0.2078 - val_accuracy: 0.3208 - val_weighted_accuracy: 0.3451 - lr: 0.0010
# Epoch 23/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0112 - accuracy: 0.6739 - weighted_accuracy: 0.6617 - val_loss: 0.2319 - val_accuracy: 0.3409 - val_weighted_accuracy: 0.3630 - lr: 0.0010
# Epoch 24/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0105 - accuracy: 0.6743 - weighted_accuracy: 0.6619 - val_loss: 0.2307 - val_accuracy: 0.3349 - val_weighted_accuracy: 0.3540 - lr: 0.0010
# Epoch 25/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0097 - accuracy: 0.6768 - weighted_accuracy: 0.6639 - val_loss: 0.2071 - val_accuracy: 0.3460 - val_weighted_accuracy: 0.3682 - lr: 0.0010
# Epoch 26/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0095 - accuracy: 0.6787 - weighted_accuracy: 0.6658 - val_loss: 0.2160 - val_accuracy: 0.3389 - val_weighted_accuracy: 0.3604 - lr: 0.0010
# Epoch 27/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0100 - accuracy: 0.6799 - weighted_accuracy: 0.6650 - val_loss: 0.2068 - val_accuracy: 0.3446 - val_weighted_accuracy: 0.3688 - lr: 0.0010
# Epoch 28/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0092 - accuracy: 0.6804 - weighted_accuracy: 0.6665 - val_loss: 0.2521 - val_accuracy: 0.3265 - val_weighted_accuracy: 0.3414 - lr: 0.0010
# Epoch 29/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0089 - accuracy: 0.6766 - weighted_accuracy: 0.6632 - val_loss: 0.2260 - val_accuracy: 0.3356 - val_weighted_accuracy: 0.3577 - lr: 0.0010
# Epoch 30/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0086 - accuracy: 0.6800 - weighted_accuracy: 0.6632 - val_loss: 0.2200 - val_accuracy: 0.3486 - val_weighted_accuracy: 0.3643 - lr: 0.0010
# Epoch 31/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0082 - accuracy: 0.6799 - weighted_accuracy: 0.6640 - val_loss: 0.2376 - val_accuracy: 0.3523 - val_weighted_accuracy: 0.3744 - lr: 0.0010
# Epoch 32/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0083 - accuracy: 0.6857 - weighted_accuracy: 0.6701 - val_loss: 0.1865 - val_accuracy: 0.3215 - val_weighted_accuracy: 0.3460 - lr: 0.0010
# Epoch 33/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0081 - accuracy: 0.6812 - weighted_accuracy: 0.6656 - val_loss: 0.2186 - val_accuracy: 0.3218 - val_weighted_accuracy: 0.3470 - lr: 0.0010
# Epoch 34/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0078 - accuracy: 0.6844 - weighted_accuracy: 0.6668 - val_loss: 0.2273 - val_accuracy: 0.3496 - val_weighted_accuracy: 0.3707 - lr: 0.0010
# Epoch 35/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0066 - accuracy: 0.6913 - weighted_accuracy: 0.6735 - val_loss: 0.2499 - val_accuracy: 0.3486 - val_weighted_accuracy: 0.3651 - lr: 0.0010
# Epoch 36/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0072 - accuracy: 0.6860 - weighted_accuracy: 0.6687 - val_loss: 0.2073 - val_accuracy: 0.3305 - val_weighted_accuracy: 0.3524 - lr: 0.0010
# Epoch 37/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0069 - accuracy: 0.6810 - weighted_accuracy: 0.6640 - val_loss: 0.2665 - val_accuracy: 0.2984 - val_weighted_accuracy: 0.3215 - lr: 0.0010
# Epoch 38/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0064 - accuracy: 0.6853 - weighted_accuracy: 0.6675 - val_loss: 0.2110 - val_accuracy: 0.3299 - val_weighted_accuracy: 0.3506 - lr: 0.0010
# Epoch 39/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0065 - accuracy: 0.6836 - weighted_accuracy: 0.6668 - val_loss: 0.2746 - val_accuracy: 0.3248 - val_weighted_accuracy: 0.3386 - lr: 0.0010
# Epoch 40/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0062 - accuracy: 0.6840 - weighted_accuracy: 0.6661 - val_loss: 0.2547 - val_accuracy: 0.3493 - val_weighted_accuracy: 0.3668 - lr: 0.0010
# Epoch 41/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0061 - accuracy: 0.6847 - weighted_accuracy: 0.6654 - val_loss: 0.2309 - val_accuracy: 0.3279 - val_weighted_accuracy: 0.3490 - lr: 0.0010
# Epoch 42/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0060 - accuracy: 0.6866 - weighted_accuracy: 0.6669 - val_loss: 0.2877 - val_accuracy: 0.3225 - val_weighted_accuracy: 0.3364 - lr: 0.0010
# Epoch 43/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0050 - accuracy: 0.6809 - weighted_accuracy: 0.6640 - val_loss: 0.2554 - val_accuracy: 0.3453 - val_weighted_accuracy: 0.3639 - lr: 0.0010
# Epoch 44/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0057 - accuracy: 0.6875 - weighted_accuracy: 0.6695 - val_loss: 0.2268 - val_accuracy: 0.3372 - val_weighted_accuracy: 0.3548 - lr: 0.0010
# Epoch 45/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0055 - accuracy: 0.6910 - weighted_accuracy: 0.6715 - val_loss: 0.2498 - val_accuracy: 0.3627 - val_weighted_accuracy: 0.3833 - lr: 0.0010
# Epoch 46/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0045 - accuracy: 0.6938 - weighted_accuracy: 0.6747 - val_loss: 0.2412 - val_accuracy: 0.3631 - val_weighted_accuracy: 0.3848 - lr: 1.0000e-04
# Epoch 47/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0040 - accuracy: 0.6892 - weighted_accuracy: 0.6695 - val_loss: 0.2450 - val_accuracy: 0.3610 - val_weighted_accuracy: 0.3825 - lr: 1.0000e-04
# Epoch 48/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0035 - accuracy: 0.6897 - weighted_accuracy: 0.6704 - val_loss: 0.2567 - val_accuracy: 0.3641 - val_weighted_accuracy: 0.3851 - lr: 1.0000e-04
# Epoch 49/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0032 - accuracy: 0.6906 - weighted_accuracy: 0.6699 - val_loss: 0.2480 - val_accuracy: 0.3624 - val_weighted_accuracy: 0.3856 - lr: 1.0000e-04
# Epoch 50/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0033 - accuracy: 0.6815 - weighted_accuracy: 0.6619 - val_loss: 0.2621 - val_accuracy: 0.3647 - val_weighted_accuracy: 0.3854 - lr: 1.0000e-04
# Epoch 51/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0029 - accuracy: 0.6843 - weighted_accuracy: 0.6653 - val_loss: 0.2621 - val_accuracy: 0.3644 - val_weighted_accuracy: 0.3841 - lr: 1.0000e-04
# Epoch 52/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0028 - accuracy: 0.6863 - weighted_accuracy: 0.6663 - val_loss: 0.2659 - val_accuracy: 0.3671 - val_weighted_accuracy: 0.3894 - lr: 1.0000e-04
# Epoch 53/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0025 - accuracy: 0.6897 - weighted_accuracy: 0.6697 - val_loss: 0.2781 - val_accuracy: 0.3647 - val_weighted_accuracy: 0.3829 - lr: 1.0000e-04
# Epoch 54/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0022 - accuracy: 0.6855 - weighted_accuracy: 0.6671 - val_loss: 0.2806 - val_accuracy: 0.3647 - val_weighted_accuracy: 0.3872 - lr: 1.0000e-04
# Epoch 55/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0024 - accuracy: 0.6906 - weighted_accuracy: 0.6711 - val_loss: 0.2778 - val_accuracy: 0.3654 - val_weighted_accuracy: 0.3846 - lr: 1.0000e-04
# Epoch 56/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0021 - accuracy: 0.6905 - weighted_accuracy: 0.6695 - val_loss: 0.2879 - val_accuracy: 0.3664 - val_weighted_accuracy: 0.3871 - lr: 1.0000e-04
# Epoch 57/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0022 - accuracy: 0.6849 - weighted_accuracy: 0.6667 - val_loss: 0.2856 - val_accuracy: 0.3587 - val_weighted_accuracy: 0.3820 - lr: 1.0000e-04
# Epoch 58/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0018 - accuracy: 0.6853 - weighted_accuracy: 0.6646 - val_loss: 0.2979 - val_accuracy: 0.3647 - val_weighted_accuracy: 0.3853 - lr: 1.0000e-04
# Epoch 59/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0019 - accuracy: 0.6876 - weighted_accuracy: 0.6689 - val_loss: 0.3035 - val_accuracy: 0.3711 - val_weighted_accuracy: 0.3923 - lr: 1.0000e-04
# Epoch 60/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0020 - accuracy: 0.6898 - weighted_accuracy: 0.6693 - val_loss: 0.2944 - val_accuracy: 0.3671 - val_weighted_accuracy: 0.3871 - lr: 1.0000e-04
# Epoch 61/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0019 - accuracy: 0.6860 - weighted_accuracy: 0.6668 - val_loss: 0.3010 - val_accuracy: 0.3654 - val_weighted_accuracy: 0.3858 - lr: 1.0000e-04
# Epoch 62/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0017 - accuracy: 0.6905 - weighted_accuracy: 0.6689 - val_loss: 0.3142 - val_accuracy: 0.3738 - val_weighted_accuracy: 0.3942 - lr: 1.0000e-04
# Epoch 63/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0020 - accuracy: 0.6865 - weighted_accuracy: 0.6660 - val_loss: 0.2812 - val_accuracy: 0.3644 - val_weighted_accuracy: 0.3870 - lr: 1.0000e-04
# Epoch 64/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0019 - accuracy: 0.6857 - weighted_accuracy: 0.6661 - val_loss: 0.3078 - val_accuracy: 0.3701 - val_weighted_accuracy: 0.3922 - lr: 1.0000e-04
# Epoch 65/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0016 - accuracy: 0.6864 - weighted_accuracy: 0.6660 - val_loss: 0.3129 - val_accuracy: 0.3654 - val_weighted_accuracy: 0.3878 - lr: 1.0000e-04
# Epoch 66/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0016 - accuracy: 0.6913 - weighted_accuracy: 0.6712 - val_loss: 0.3154 - val_accuracy: 0.3704 - val_weighted_accuracy: 0.3919 - lr: 1.0000e-04
# Epoch 67/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0016 - accuracy: 0.6905 - weighted_accuracy: 0.6701 - val_loss: 0.3106 - val_accuracy: 0.3694 - val_weighted_accuracy: 0.3909 - lr: 1.0000e-04
# Epoch 68/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0016 - accuracy: 0.6896 - weighted_accuracy: 0.6680 - val_loss: 0.3183 - val_accuracy: 0.3604 - val_weighted_accuracy: 0.3827 - lr: 1.0000e-04
# Epoch 69/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0015 - accuracy: 0.6892 - weighted_accuracy: 0.6697 - val_loss: 0.3211 - val_accuracy: 0.3641 - val_weighted_accuracy: 0.3837 - lr: 1.0000e-04
# Epoch 70/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0018 - accuracy: 0.6938 - weighted_accuracy: 0.6727 - val_loss: 0.3175 - val_accuracy: 0.3654 - val_weighted_accuracy: 0.3852 - lr: 1.0000e-04
# Epoch 71/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0015 - accuracy: 0.6900 - weighted_accuracy: 0.6688 - val_loss: 0.3183 - val_accuracy: 0.3711 - val_weighted_accuracy: 0.3916 - lr: 1.0000e-04
# Epoch 72/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0014 - accuracy: 0.6840 - weighted_accuracy: 0.6637 - val_loss: 0.3236 - val_accuracy: 0.3644 - val_weighted_accuracy: 0.3844 - lr: 1.0000e-04
# Epoch 73/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0014 - accuracy: 0.6861 - weighted_accuracy: 0.6670 - val_loss: 0.3156 - val_accuracy: 0.3664 - val_weighted_accuracy: 0.3880 - lr: 1.0000e-04
# Epoch 74/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0015 - accuracy: 0.6846 - weighted_accuracy: 0.6640 - val_loss: 0.3251 - val_accuracy: 0.3698 - val_weighted_accuracy: 0.3901 - lr: 1.0000e-04
# Epoch 75/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0014 - accuracy: 0.6921 - weighted_accuracy: 0.6723 - val_loss: 0.3232 - val_accuracy: 0.3607 - val_weighted_accuracy: 0.3815 - lr: 1.0000e-04
# Epoch 76/500
# 373/373 [==============================] - 26s 71ms/step - loss: 0.0016 - accuracy: 0.6862 - weighted_accuracy: 0.6658 - val_loss: 0.3366 - val_accuracy: 0.3728 - val_weighted_accuracy: 0.3928 - lr: 1.0000e-04
# Epoch 77/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0014 - accuracy: 0.6864 - weighted_accuracy: 0.6655 - val_loss: 0.3285 - val_accuracy: 0.3711 - val_weighted_accuracy: 0.3931 - lr: 1.0000e-04
# Epoch 78/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0013 - accuracy: 0.6858 - weighted_accuracy: 0.6645 - val_loss: 0.3363 - val_accuracy: 0.3667 - val_weighted_accuracy: 0.3887 - lr: 1.0000e-04
# Epoch 79/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0013 - accuracy: 0.6851 - weighted_accuracy: 0.6642 - val_loss: 0.3275 - val_accuracy: 0.3698 - val_weighted_accuracy: 0.3920 - lr: 1.0000e-04
# Epoch 80/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0012 - accuracy: 0.6900 - weighted_accuracy: 0.6686 - val_loss: 0.3354 - val_accuracy: 0.3698 - val_weighted_accuracy: 0.3903 - lr: 1.0000e-04
# Epoch 81/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0013 - accuracy: 0.6907 - weighted_accuracy: 0.6698 - val_loss: 0.3338 - val_accuracy: 0.3721 - val_weighted_accuracy: 0.3948 - lr: 1.0000e-04
# Epoch 82/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0013 - accuracy: 0.6871 - weighted_accuracy: 0.6665 - val_loss: 0.3460 - val_accuracy: 0.3745 - val_weighted_accuracy: 0.3945 - lr: 1.0000e-04
# Epoch 83/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0012 - accuracy: 0.6851 - weighted_accuracy: 0.6652 - val_loss: 0.3349 - val_accuracy: 0.3610 - val_weighted_accuracy: 0.3824 - lr: 1.0000e-04
# Epoch 84/500
# 373/373 [==============================] - 26s 70ms/step - loss: 0.0013 - accuracy: 0.6873 - weighted_accuracy: 0.6677 - val_loss: 0.3292 - val_accuracy: 0.3667 - val_weighted_accuracy: 0.3879 - lr: 1.0000e-04
# Epoch 85/500
# 373/373 [==============================] - 27s 71ms/step - loss: 0.0011 - accuracy: 0.6835 - weighted_accuracy: 0.6633 - val_loss: 0.3507 - val_accuracy: 0.3607 - val_weighted_accuracy: 0.3819 - lr: 1.0000e-04
# Model and training history saved successfully.

# %%
# Load the model
# import tensorflow as tf
# model_path = '/content/drive/My Drive/datasets/openmic-2018/model_with_attention.tf'
# training_model = tf.keras.models.load_model(model_path)

# %%
from sklearn.metrics import accuracy_score, hamming_loss, classification_report, precision_recall_fscore_support

label_dict = {"accordion": 0, "banjo": 1, "bass": 2, "cello": 3, "clarinet": 4, "cymbals": 5, "drums": 6, "flute": 7, "guitar": 8, "mallet_percussion": 9, "mandolin": 10, "organ": 11, "piano": 12, "saxophone": 13, "synthesizer": 14, "trombone": 15, "trumpet": 16, "ukulele": 17, "violin": 18, "voice": 19}
# Step 1: Extract and sort class names based on their label values
target_names = [key for key, value in sorted(label_dict.items(), key=lambda item: item[1])]

# Predict the labels for the test set
y_pred = training_model.predict(X_test) # [:5]
y_pred_binary = (y_pred >= 0.5).astype(int)

small_true = y_test # [:5]

# Calculate Exact Match Ratio (EMR)
def exact_match_ratio(y_true, y_pred):
    return np.mean([np.array_equal(y_true[i], y_pred[i]) for i in range(len(y_true))])

emr = exact_match_ratio(small_true, y_pred_binary)
hl = hamming_loss(small_true, y_pred_binary)
# accuracy = accuracy_score(small_true, y_pred_binary)

# Calculate mean average precision (mAP)
precision, recall, f1, _ = precision_recall_fscore_support(small_true, y_pred_binary, average=None)
mean_average_precision = precision.mean()

print(f"Hamming Loss: {hl}")
print(classification_report(small_true, y_pred_binary, target_names=target_names))

print(f"Exact Match Ratio (EMR): {emr}")
print(f"Mean Average Precision (mAP): {mean_average_precision}")
# Out:
# 159/159 [==============================] - 3s 20ms/step
# Hamming Loss: 0.05503441494591937
#                    precision    recall  f1-score   support
#
#         accordion       1.00      0.02      0.03       233
#             banjo       0.64      0.15      0.25       244
#              bass       1.00      0.02      0.04       226
#             cello       0.84      0.09      0.16       302
#          clarinet       0.50      0.00      0.01       321
#           cymbals       0.74      0.25      0.37       317
#             drums       0.77      0.32      0.45       311
#             flute       0.72      0.06      0.12       328
#            guitar       0.93      0.12      0.21       315
# mallet_percussion       0.86      0.09      0.16       280
#          mandolin       0.74      0.26      0.39       329
#             organ       0.65      0.09      0.16       221
#             piano       0.82      0.56      0.66       304
#         saxophone       0.82      0.04      0.07       389
#       synthesizer       0.94      0.10      0.18       305
#          trombone       0.86      0.02      0.03       393
#           trumpet       0.91      0.04      0.08       453
#           ukulele       0.82      0.21      0.34       314
#            violin       0.68      0.51      0.59       458
#             voice       0.92      0.05      0.10       236
#
#         micro avg       0.76      0.16      0.26      6279
#         macro avg       0.81      0.15      0.22      6279
#      weighted avg       0.80      0.16      0.23      6279
#       samples avg       0.17      0.15      0.15      6279
#
# Exact Match Ratio (EMR): 0.25231071779744346
# Mean Average Precision (mAP): 0.8072054221988848
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def exact_match_ratio(y_true_list, y_pred_binary, mlb):
    # Convert one-hot encoded predictions back to multi-label format
    y_pred_labels = mlb.inverse_transform(y_pred_binary)

    # Calculate exact match ratio
    exact_matches = sum(1 for true, pred in zip(y_true_list, y_pred_labels) if set(true) == set(pred))
    return exact_matches / len(y_true_list)


emr = exact_match_ratio(y_test_list, y_pred_binary, mlb)
print(f"Exact Match Ratio (EMR): {emr}")
# Out:
# Exact Match Ratio (EMR): 0.27984267453294004

# %%
# Save the test sample keys, true labels, and predicted labels to a DataFrame
test_labels_df = pd.DataFrame({
    'sample_key': test_sample_keys,
    'true_labels': y_test_list,
    'predicted_labels': [list(pred) for pred in y_pred]
})

# Save the DataFrame to a CSV file
test_labels_df.to_csv('/content/drive/My Drive/datasets/openmic-2018/test_sample_keys_labels_predictions.csv', index=False)

# Example usage for inspecting the data
for i in range(5):
    print(f"Sample Key: {test_sample_keys[i]}")
    print(f"True Labels: {y_test_list[i]}")
    print(f"Predicted Labels: {y_pred[i]}")
# Out:
# Sample Key: 000178_3840
# True Labels: ['voice']
# Predicted Labels: [3.5992245e-05 1.9129699e-03 2.2733393e-03 1.0072567e-03 1.6268459e-04
#  4.4644973e-03 4.1702524e-02 9.0810545e-03 1.8029569e-03 3.4005910e-02
#  5.0572428e-04 2.3249080e-04 2.7309083e-03 6.7996437e-04 1.1561167e-02
#  7.1192882e-04 6.2487402e-04 1.2569975e-03 3.4291288e-04 3.6051860e-01]
# Sample Key: 000308_61440
# True Labels: ['bass']
# Predicted Labels: [0.00119483 0.00138895 0.25656658 0.01708469 0.02196496 0.0056369
#  0.00219774 0.034195   0.00779609 0.0100468  0.00167104 0.00278218
#  0.00532581 0.03470495 0.1413422  0.00707062 0.00372197 0.00376355
#  0.00207321 0.02383199]
# Sample Key: 000312_184320
# True Labels: []
# Predicted Labels: [1.1516191e-05 8.0926652e-04 9.6009243e-03 1.5246637e-04 3.3054941e-05
#  3.5928718e-03 1.7399275e-01 1.2073954e-04 1.4245290e-05 8.2164044e-03
#  6.2464591e-04 3.2237465e-05 3.8100518e-03 1.8756119e-04 9.7745903e-02
#  1.0346808e-02 1.5443696e-03 4.9702608e-04 8.6523251e-06 1.5049480e-03]
# Sample Key: 000319_145920
# True Labels: ['bass', 'bass']
# Predicted Labels: [2.8403170e-04 8.9390675e-04 3.4468842e-01 7.9439525e-03 4.9485331e-03
#  1.5435195e-02 1.5629275e-03 2.8545572e-03 6.0678632e-03 1.0183655e-02
#  4.6591992e-03 2.5793186e-03 1.6341439e-02 7.1230610e-03 3.8573176e-02
#  1.0925620e-03 9.8617224e-04 1.0390912e-02 5.5552175e-04 3.4984066e-03]
# Sample Key: 000321_218880
# True Labels: ['synthesizer']
# Predicted Labels: [1.3855156e-04 3.5647149e-03 8.1840910e-02 9.2726899e-03 5.5738178e-04
#  8.2638338e-03 2.8576113e-02 2.3959068e-04 5.4585040e-02 5.1128608e-03
#  4.2042506e-04 4.7884925e-04 3.7426495e-03 3.4910417e-03 5.2537423e-02
#  3.4181771e-03 2.3252910e-03 1.7642640e-03 8.3111161e-05 3.0526144e-02]

# %%
import tensorflow as tf

def h_swish(x):
    return x * tf.nn.relu6(x + 3) / 6

# Load the model
model_path = '/content/drive/My Drive/datasets/openmic-2018/model_with_attention.tf'
with tf.keras.utils.custom_object_scope({'h_swish': h_swish}):
    loaded_model = tf.keras.models.load_model(model_path)

# %%
visualization_model = tf.keras.Model(
    inputs=loaded_model.input,
    outputs=[
        loaded_model.get_layer('multiply_1').output,  # Channel attention
        loaded_model.get_layer('tf.math.multiply').output,  # Height coordinate attention
        loaded_model.get_layer('tf.math.multiply_1').output,  # Width coordinate attention
    ]
)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_attention_maps(model, x_data, sample_index=0):
    channel_attention, height_attention, width_attention = model.predict(np.expand_dims(x_data[sample_index], axis=0))

    plt.figure(figsize=(20, 5))

    plt.subplot(1, 4, 1)
    plt.title('Original Spectrogram')
    plt.imshow(x_data[sample_index].squeeze(), aspect='auto', cmap='viridis')
    plt.colorbar()

    plt.subplot(1, 4, 2)
    plt.title('Channel Attention')
    channel_att_map = np.mean(channel_attention.squeeze(), axis=-1)
    plt.imshow(channel_att_map, aspect='auto', cmap='viridis')
    plt.colorbar()

    plt.subplot(1, 4, 3)
    plt.title('Height Coordinate Attention')
    height_att_map = np.mean(height_attention.squeeze(), axis=-1)
    plt.imshow(height_att_map, aspect='auto', cmap='viridis')
    plt.colorbar()

    plt.subplot(1, 4, 4)
    plt.title('Width Coordinate Attention')
    width_att_map = np.mean(width_attention.squeeze(), axis=-1)
    plt.imshow(width_att_map, aspect='auto', cmap='viridis')
    plt.colorbar()

    plt.tight_layout()
    plt.show()

# Use the function
plot_attention_maps(visualization_model, X_test, sample_index=10)
# Out:
# 1/1 [==============================] - 1s 600ms/step

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the training history
history_df = pd.read_csv('/content/drive/My Drive/datasets/openmic-2018/training_history_with_attention.csv')

# Plotting the training history
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plotting Training Loss
axes[0, 0].plot(history_df['loss'], label='Train Loss')
axes[0, 0].set_title('Training Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()

# Plotting Training Accuracy
axes[0, 1].plot(history_df['accuracy'], label='Train Accuracy')
axes[0, 1].set_title('Training Accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()

# Plotting Validation Loss
axes[1, 0].plot(history_df['val_loss'], label='Validation Loss')
axes[1, 0].set_title('Validation Loss')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].set_ylabel('Loss')
axes[1, 0].legend()

# Plotting Validation Accuracy
axes[1, 1].plot(history_df['val_accuracy'], label='Validation Accuracy')
axes[1, 1].set_title('Validation Accuracy')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].set_ylabel('Accuracy')
axes[1, 1].legend()

# Adjust layout
plt.tight_layout()
plt.show()
